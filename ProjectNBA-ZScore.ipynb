# %% [markdown]
# Connect to Google Drive

# %%
from google.colab import drive
import pandas as pd

# Mount to Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Load final_df into df

# %%
# Provide full path to final_df CSV file in Google Drive
final_df = '/content/drive/MyDrive/COMP 333/NBA-Data/final_df.csv'

# Load the CSV file into a DataFrame
final_df = pd.read_csv(final_df, sep=',')

final_df
# Out:
#                                          Player   Rk    Pos  Age   Tm   G  GS  \
# 0                                    Al Horford  204      C   30  BOS  68  68
# 1                                 Allan Houston  181     SG   28  NYK  82  82
# 2                                 Allen Iverson  203     SG   32  DEN  82  82
# 3                               Alonzo Mourning  269      C   28  MIA  46  46
# 4                             Amar'e Stoudemire  377     PF   27  PHO  82  82
# ...                                         ...  ...    ...  ...  ...  ..  ..
# 1480                        ÃÂÃÂlex Abrines    1     SG   24  OKC  75   8
# 1481                        ÃÂÃÂscar Torres  400     SG   25  HOU  65  13
# 1482  ÃÂ
# ÃÂ arÃÂ
# ÃÂ«nas JasikeviÃÂÃÂius  211  SG-PG   30  TOT  63   3
# 1483                           ÃÂ
# ÃÂ½an Tabak  381      C   27  TOT  57  34
# 1484              ÃÂ
# ÃÂ½arko ÃÂÃÂabarkapa   69     PF   24  GSW  61   0
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Select the columns to normalize
columns_to_normalize = ['G', 'GS', 'MP', 'FGA', 'PTS', '2PA', '2P', '3PA', '3P', 'FG', 'FGA']

# Create a StandardScaler object
scaler = StandardScaler()

# Fit and transform the selected columns
final_df[columns_to_normalize] = scaler.fit_transform(final_df[columns_to_normalize])

print(final_df[columns_to_normalize])
# Out:
#              G        GS        MP       FGA       PTS       2PA        2P  \
# 0     0.616042  1.722262  1.511704  1.224243  1.082975  1.061923  1.166276
# 1     1.761820  2.262972  2.291078  2.104654  2.107959  2.345676  2.259805
# 2     1.761820  2.262972  2.686950  2.937475  3.312764  3.271172  3.008009
# 3    -1.184466  0.872574  2.229223  1.700141  2.179888  2.703933  2.720238
# 4     1.761820  2.262972  1.796238  2.080859  2.719353  3.181608  3.641104
# ...        ...       ...       ...       ...       ...       ...       ...
# 1480  1.188931 -0.595067 -0.616110 -0.655553 -0.589367 -1.117471 -1.078336
# 1481  0.370518 -0.401956 -0.442916 -0.346220 -0.355599 -0.400958 -0.445240
# 1482  0.206835 -0.788178 -0.578997 -0.370015 -0.337617 -0.490522 -0.560349
# 1483 -0.284212  0.409109 -0.343947 -0.322425 -0.463492  0.196136  0.130301
# 1484  0.043153 -0.904044 -1.457338 -0.893502 -0.841118 -0.639796 -0.733011
#
#            3PA        3P        FG       FGA
# ...
